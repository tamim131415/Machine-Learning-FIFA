# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Set display options and seaborn style
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)
sns.set_style(style='darkgrid')
warnings.filterwarnings('ignore')

# Load the dataset
fd = pd.read_csv('final-fd.csv')
print(fd.columns)

# Data preprocessing
fd['BMI_floor'] = fd['BMI'].apply(np.floor)
fd['Value_of_log'] = np.log10(fd['Value'])

# Dropping useless columns
useless_columns = ['BMI', 'Value']
fd = fd.drop(useless_columns, axis=1)
print(fd.columns)

# Create correlation matrix
corr_matrix = fd.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Index(['Age', 'Potential', 'Value', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed',
#        'ShotPower', 'Penalties', 'BMI', 'Work Rate_NUM'],
#       dtype='object')
# Index(['Age', 'Potential', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed', 'ShotPower',
#        'Penalties', 'Work Rate_NUM', 'BMI_floor', 'Value_of_log'],
#       dtype='object')

# %% [markdown]
# **DF**

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Set display options and seaborn style
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)
sns.set_style(style='darkgrid')
warnings.filterwarnings('ignore')

# Load the dataset
df = pd.read_csv('final-df.csv')
print(fd.columns)

# Data preprocessing
df['BMI_floor'] = df['BMI'].apply(np.floor)
df['Value_of_log'] = np.log10(df['Value'])

useless_columns = ['BMI','Value']
df = df.drop(useless_columns, axis=1)
print(df.columns)

# Create correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Index(['Age', 'Potential', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed', 'ShotPower',
#        'Penalties', 'Work Rate_NUM', 'BMI_floor', 'Value_of_log'],
#       dtype='object')
# Index(['Age', 'Potential', 'ShortPassing', 'Balance', 'Strength',
#        'Interceptions', 'SlidingTackle', 'Work Rate_NUM', 'BMI_floor',
#        'Value_of_log'],
#       dtype='object')

# %% [markdown]
# **MF**

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Set display options and seaborn style
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)
sns.set_style(style='darkgrid')
warnings.filterwarnings('ignore')

# Load the dataset
mf = pd.read_csv('final-mf.csv')
print(fd.columns)

# Data preprocessing
# Data preprocessing
mf['BMI_floor'] = mf['BMI'].apply(np.floor)
mf['Value_of_log'] = np.log10(mf['Value'])

useless_columns = ['BMI','Value']
mf = mf.drop(useless_columns, axis=1)
print(mf.columns)

# Create correlation matrix
corr_matrix = mf.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Index(['Age', 'Potential', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed', 'ShotPower',
#        'Penalties', 'Work Rate_NUM', 'BMI_floor', 'Value_of_log'],
#       dtype='object')
# Index(['Age', 'Potential', 'Crossing', 'ShortPassing', 'Dribbling',
#        'LongPassing', 'BallControl', 'SprintSpeed', 'LongShots', 'Aggression',
#        'Vision', 'Work Rate_NUM', 'BMI_floor', 'Value_of_log'],
#       dtype='object')

# %% [markdown]
# **GK**

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Set display options and seaborn style
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)
sns.set_style(style='darkgrid')
warnings.filterwarnings('ignore')

# Load the dataset
gk = pd.read_csv('final-gk.csv')
print(gk.columns)


# Create correlation matrix
corr_matrix = gk.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Index(['Age', 'Potential', 'Value', 'GKDiving', 'GKHandling', 'GKKicking',
#        'GKPositioning', 'GKReflexes'],
#       dtype='object')
