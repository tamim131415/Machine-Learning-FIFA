# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import jarque_bera, normaltest, ttest_1samp
from statsmodels.stats.stattools import durbin_watson

# Load your dataset from a CSV file
csv_file_path = "/content/drive/MyDrive/Dataset/Final Dataset Fifa/final-fd.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Print the column names to verify their existence
print(df.columns)
# Out:
# Index(['Age', 'Potential', 'Value', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed',
#        'ShotPower', 'Penalties', 'BMI', 'Work Rate_NUM'],
#       dtype='object')

# %%
# List of numerical columns to perform tests on
numerical_columns = ['Age', 'Potential', 'Value', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed',
       'ShotPower', 'Penalties', 'BMI', 'Work Rate_NUM']

# Iterate through each numerical column
for col in numerical_columns:
    data = df[col]

    # JB test
    jb_stat, jb_p_value = jarque_bera(data)
    print(f'Jarque-Bera Test for {col}:')
    print(f'  JB Test Statistic: {jb_stat}')
    print(f'  JB P-Value: {jb_p_value}')

    # P-value test
    p_value_stat, p_value = normaltest(data)
    print(f'P-Value Test for {col}:')
    print(f'  P-Value Test Statistic: {p_value_stat}')
    print(f'  P-Value: {p_value}')

    # T-test (one-sample T-test against a known population mean)
    population_mean = 0  # Replace with your known population mean
    t_stat, t_p_value = ttest_1samp(data, population_mean)
    print(f'T-Test for {col}:')
    print(f'  T-Test Statistic: {t_stat}')
    print(f'  T-Test P-Value: {t_p_value}')

    # Standard error
    std_error = np.std(data, ddof=1) / np.sqrt(len(data))
    print(f'Standard Error for {col}: {std_error}')

    # DW test
    # Assuming your data is time series data, you can perform the DW test
    dw_stat = durbin_watson(data)
    print(f'Durbin-Watson Test for {col}:')
    print(f'  Durbin-Watson Statistic: {dw_stat}')
# Out:
# Jarque-Bera Test for Age:
#   JB Test Statistic: 67.28712567916433
#   JB P-Value: 2.447858486871244e-15
# P-Value Test for Age:
#   P-Value Test Statistic: 183.04368770364954
#   P-Value: 1.7888265888464298e-40
# T-Test for Age:
#   T-Test Statistic: 242.36693544936253
#   T-Test P-Value: 0.0
# Standard Error for Age: 0.1089920964385389
# Durbin-Watson Test for Age:
#   Durbin-Watson Statistic: 0.04601855592549768
# Jarque-Bera Test for Potential:
#   JB Test Statistic: 46.65675764599115
#   JB P-Value: 7.389478764576348e-11
# P-Value Test for Potential:
#   P-Value Test Statistic: 44.25154323201208
#   P-Value: 2.459798199693311e-10
# T-Test for Potential:
#   T-Test Statistic: 572.6435315970136
#   T-Test P-Value: 0.0
# Standard Error for Potential: 0.12577128104792412
# Durbin-Watson Test for Potential:
#   Durbin-Watson Statistic: 0.008641123424041426
# Jarque-Bera Test for Value:
#   JB Test Statistic: 1213440.1346365614
#   JB P-Value: 0.0
# P-Value Test for Value:
#   P-Value Test Statistic: 2980.883732549376
#   P-Value: 0.0
# T-Test for Value:
#   T-Test Statistic: 17.29558454912061
#   T-Test P-Value: 1.514635973330514e-62
# Standard Error for Value: 220798.2135560974
# Durbin-Watson Test for Value:
#   Durbin-Watson Statistic: 0.8851338543131
# Jarque-Bera Test for Finishing:
#   JB Test Statistic: 49.282136973613135
#   JB P-Value: 1.9884740511636473e-11
# P-Value Test for Finishing:
#   P-Value Test Statistic: 46.58492533880133
#   P-Value: 7.65970409824046e-11
# T-Test for Finishing:
#   T-Test Statistic: 445.0262338936635
#   T-Test P-Value: 0.0
# Standard Error for Finishing: 0.1556522772323122
# Durbin-Watson Test for Finishing:
#   Durbin-Watson Statistic: 0.009570218898058749
# Jarque-Bera Test for HeadingAccuracy:
#   JB Test Statistic: 1.7531994467914598
#   JB P-Value: 0.41619568886743274
# P-Value Test for HeadingAccuracy:
#   P-Value Test Statistic: 1.842146525621191
#   P-Value: 0.3980915548619712
# T-Test for HeadingAccuracy:
#   T-Test Statistic: 344.3714987699216
#   T-Test P-Value: 0.0
# Standard Error for HeadingAccuracy: 0.19424360040807628
# Durbin-Watson Test for HeadingAccuracy:
#   Durbin-Watson Statistic: 0.02292751057168561
# Jarque-Bera Test for ShortPassing:
#   JB Test Statistic: 0.6709190145554467
#   JB P-Value: 0.7150094588050055
# P-Value Test for ShortPassing:
#   P-Value Test Statistic: 0.7365743742231876
#   P-Value: 0.6919184430933842
# T-Test for ShortPassing:
#   T-Test Statistic: 352.7297148526758
#   T-Test P-Value: 0.0
# Standard Error for ShortPassing: 0.17604266034935565
# Durbin-Watson Test for ShortPassing:
#   Durbin-Watson Statistic: 0.010205874852677158
# Jarque-Bera Test for Volleys:
#   JB Test Statistic: 10.998549657356724
#   JB P-Value: 0.004089736122731414
# P-Value Test for Volleys:
#   P-Value Test Statistic: 11.868453398195166
#   P-Value: 0.0026472690988026014
# T-Test for Volleys:
#   T-Test Statistic: 287.03474693478915
#   T-Test P-Value: 0.0
# Standard Error for Volleys: 0.2180272866037143
# Durbin-Watson Test for Volleys:
#   Durbin-Watson Statistic: 0.02020783895669339
# Jarque-Bera Test for Dribbling:
#   JB Test Statistic: 20.59828496765555
#   JB P-Value: 3.3661948478077046e-05
# P-Value Test for Dribbling:
#   P-Value Test Statistic: 18.27910695574742
#   P-Value: 0.00010733524637537941
# T-Test for Dribbling:
#   T-Test Statistic: 409.26146224793587
#   T-Test P-Value: 0.0
# Standard Error for Dribbling: 0.16134468278866912
# Durbin-Watson Test for Dribbling:
#   Durbin-Watson Statistic: 0.009393015523589714
# Jarque-Bera Test for BallControl:
#   JB Test Statistic: 15.787904067594672
#   JB P-Value: 0.0003729925790609465
# P-Value Test for BallControl:
#   P-Value Test Statistic: 15.648531628139674
#   P-Value: 0.0003999120883765649
# T-Test for BallControl:
#   T-Test Statistic: 439.2165866554828
#   T-Test P-Value: 0.0
# Standard Error for BallControl: 0.153424151564798
# Durbin-Watson Test for BallControl:
#   Durbin-Watson Statistic: 0.007238634059697755
# Jarque-Bera Test for SprintSpeed:
#   JB Test Statistic: 349.31711213181194
#   JB P-Value: 1.4020157207549456e-76
# P-Value Test for SprintSpeed:
#   P-Value Test Statistic: 234.59827020218364
#   P-Value: 1.1419126750222319e-51
# T-Test for SprintSpeed:
#   T-Test Statistic: 277.96020282965367
#   T-Test P-Value: 0.0
# Standard Error for SprintSpeed: 0.25407093289351584
# Durbin-Watson Test for SprintSpeed:
#   Durbin-Watson Statistic: 0.04621130317089033
# Jarque-Bera Test for ShotPower:
#   JB Test Statistic: 8.48233129169179
#   JB P-Value: 0.014390807477744417
# P-Value Test for ShotPower:
#   P-Value Test Statistic: 9.08948795764179
#   P-Value: 0.010622892053482491
# T-Test for ShotPower:
#   T-Test Statistic: 414.4540877402453
#   T-Test P-Value: 0.0
# Standard Error for ShotPower: 0.17000507068607237
# Durbin-Watson Test for ShotPower:
#   Durbin-Watson Statistic: 0.009664915443371955
# Jarque-Bera Test for Penalties:
#   JB Test Statistic: 23.156350141947946
#   JB P-Value: 9.368335949013334e-06
# P-Value Test for Penalties:
#   P-Value Test Statistic: 15.637362747877784
#   P-Value: 0.00040215162093934004
# T-Test for Penalties:
#   T-Test Statistic: 351.66024513531016
#   T-Test P-Value: 0.0
# Standard Error for Penalties: 0.18633077390629768
# Durbin-Watson Test for Penalties:
#   Durbin-Watson Statistic: 0.021665548781435985
# Jarque-Bera Test for BMI:
#   JB Test Statistic: 396.11790296771375
#   JB P-Value: 9.640294005228708e-87
# P-Value Test for BMI:
#   P-Value Test Statistic: 128.7585630566831
#   P-Value: 1.0975726673587911e-28
# T-Test for BMI:
#   T-Test Statistic: 695.8457633002547
#   T-Test P-Value: 0.0
# Standard Error for BMI: 0.03320712925147814
# Durbin-Watson Test for BMI:
#   Durbin-Watson Statistic: 0.007748179491424147
# Jarque-Bera Test for Work Rate_NUM:
#   JB Test Statistic: 251.5125394057971
#   JB P-Value: 2.4251913094533175e-55
# P-Value Test for Work Rate_NUM:
#   P-Value Test Statistic: 8810.62547663759
#   P-Value: 0.0
# T-Test for Work Rate_NUM:
#   T-Test Statistic: 68.42148952609952
#   T-Test P-Value: 0.0
# Standard Error for Work Rate_NUM: 0.05988597245640105
# Durbin-Watson Test for Work Rate_NUM:
#   Durbin-Watson Statistic: 0.5361298995924884

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Load your dataset (replace 'your_dataset.csv' with the actual file path)
data = pd.read_csv('final-fd.csv')

# Extract the predictor variables (independent variables) for which you want to check multicollinearity
# Replace 'X1', 'X2', 'X3', etc. with the actual column names of your predictor variables
X = data[['Age', 'Potential', 'Value', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'BallControl', 'SprintSpeed',
       'ShotPower', 'Penalties', 'BMI', 'Work Rate_NUM']]

# Add a constant (intercept) term to the predictor variables
X['intercept'] = 1

# Calculate VIF values
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display the VIF values
print(vif)
# Out:
#            Variable         VIF
# 0               Age    4.134639
# 1         Potential    5.159410
# 2             Value    1.648926
# 3         Finishing    5.680155
# 4   HeadingAccuracy    2.475547
# 5      ShortPassing    3.655907
# 6           Volleys    3.515040
# 7         Dribbling    5.170225
# 8       BallControl    7.228989
# 9       SprintSpeed    1.719306
# 10        ShotPower    3.295521
# 11        Penalties    1.930449
# 12              BMI    1.132264
# 13    Work Rate_NUM    1.082589
# 14        intercept  726.429708
