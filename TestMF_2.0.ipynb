# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import jarque_bera, normaltest, ttest_1samp
from statsmodels.stats.stattools import durbin_watson

# Load your dataset from a CSV file
csv_file_path = "/content/drive/MyDrive/Dataset/Final Dataset Fifa/final-mf.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Print the column names to verify their existence
print(df.columns)
# Out:
# Index(['Age', 'Potential', 'Value', 'Crossing', 'ShortPassing', 'Dribbling',
#        'LongPassing', 'BallControl', 'SprintSpeed', 'LongShots', 'Aggression',
#        'Vision', 'BMI', 'Work Rate_NUM'],
#       dtype='object')

# %%
# List of numerical columns to perform tests on
numerical_columns = ['Age', 'Potential', 'Value', 'Crossing', 'ShortPassing', 'Dribbling',
       'LongPassing', 'BallControl', 'SprintSpeed', 'LongShots', 'Aggression',
       'Vision', 'BMI', 'Work Rate_NUM']

# Iterate through each numerical column
for col in numerical_columns:
    data = df[col]

    # JB test
    jb_stat, jb_p_value = jarque_bera(data)
    print(f'Jarque-Bera Test for {col}:')
    print(f'  JB Test Statistic: {jb_stat}')
    print(f'  JB P-Value: {jb_p_value}')

    # P-value test
    p_value_stat, p_value = normaltest(data)
    print(f'P-Value Test for {col}:')
    print(f'  P-Value Test Statistic: {p_value_stat}')
    print(f'  P-Value: {p_value}')

    # T-test (one-sample T-test against a known population mean)
    population_mean = 0  # Replace with your known population mean
    t_stat, t_p_value = ttest_1samp(data, population_mean)
    print(f'T-Test for {col}:')
    print(f'  T-Test Statistic: {t_stat}')
    print(f'  T-Test P-Value: {t_p_value}')

    # Standard error
    std_error = np.std(data, ddof=1) / np.sqrt(len(data))
    print(f'Standard Error for {col}: {std_error}')

    # DW test
    # Assuming your data is time series data, you can perform the DW test
    dw_stat = durbin_watson(data)
    print(f'Durbin-Watson Test for {col}:')
    print(f'  Durbin-Watson Statistic: {dw_stat}')
# Out:
# Jarque-Bera Test for Age:
#   JB Test Statistic: 204.88264287596152
#   JB P-Value: 3.238168029023175e-45
# P-Value Test for Age:
#   P-Value Test Statistic: 282.5518110480175
#   P-Value: 4.412185926615888e-62
# T-Test for Age:
#   T-Test Statistic: 417.04530291656596
#   T-Test P-Value: 0.0
# Standard Error for Age: 0.06145721457907089
# Durbin-Watson Test for Age:
#   Durbin-Watson Statistic: 0.0443325740770137
# Jarque-Bera Test for Potential:
#   JB Test Statistic: 39.46691603460913
#   JB P-Value: 2.6907173196393845e-09
# P-Value Test for Potential:
#   P-Value Test Statistic: 38.81639520998726
#   P-Value: 3.7250051409552224e-09
# T-Test for Potential:
#   T-Test Statistic: 946.7487520289654
#   T-Test P-Value: 0.0
# Standard Error for Potential: 0.07724376981095785
# Durbin-Watson Test for Potential:
#   Durbin-Watson Statistic: 0.008827346922991051
# Jarque-Bera Test for Value:
#   JB Test Statistic: 543460.3719265755
#   JB P-Value: 0.0
# P-Value Test for Value:
#   P-Value Test Statistic: 6257.805606727911
#   P-Value: 0.0
# T-Test for Value:
#   T-Test Statistic: 33.389529117338
#   T-Test P-Value: 8.81398598768618e-223
# Standard Error for Value: 131901.02777640763
# Durbin-Watson Test for Value:
#   Durbin-Watson Statistic: 0.789713672849014
# Jarque-Bera Test for Crossing:
#   JB Test Statistic: 95.40766408909865
#   JB P-Value: 1.9164124227176903e-21
# P-Value Test for Crossing:
#   P-Value Test Statistic: 90.47140962846193
#   P-Value: 2.2614292969228806e-20
# T-Test for Crossing:
#   T-Test Statistic: 485.36995013690614
#   T-Test P-Value: 0.0
# Standard Error for Crossing: 0.1279899179369471
# Durbin-Watson Test for Crossing:
#   Durbin-Watson Statistic: 0.02721194212661435
# Jarque-Bera Test for ShortPassing:
#   JB Test Statistic: 8.394792361233893
#   JB P-Value: 0.015034673472283626
# P-Value Test for ShortPassing:
#   P-Value Test Statistic: 7.361849006595963
#   P-Value: 0.025199666887604485
# T-Test for ShortPassing:
#   T-Test Statistic: 717.1697251370738
#   T-Test P-Value: 0.0
# Standard Error for ShortPassing: 0.09597703175109695
# Durbin-Watson Test for ShortPassing:
#   Durbin-Watson Statistic: 0.007488668454729076
# Jarque-Bera Test for Dribbling:
#   JB Test Statistic: 28.97835106584911
#   JB P-Value: 5.09836611112847e-07
# P-Value Test for Dribbling:
#   P-Value Test Statistic: 22.421665129996004
#   P-Value: 1.3526868854466334e-05
# T-Test for Dribbling:
#   T-Test Statistic: 699.2785329321632
#   T-Test P-Value: 0.0
# Standard Error for Dribbling: 0.09874162046874105
# Durbin-Watson Test for Dribbling:
#   Durbin-Watson Statistic: 0.013813870246017667
# Jarque-Bera Test for LongPassing:
#   JB Test Statistic: 115.27149037162032
#   JB P-Value: 9.313521156050088e-26
# P-Value Test for LongPassing:
#   P-Value Test Statistic: 108.53300343562712
#   P-Value: 2.706186677940957e-24
# T-Test for LongPassing:
#   T-Test Statistic: 526.9145141492149
#   T-Test P-Value: 0.0
# Standard Error for LongPassing: 0.12198139281054265
# Durbin-Watson Test for LongPassing:
#   Durbin-Watson Statistic: 0.01705490381073178
# Jarque-Bera Test for BallControl:
#   JB Test Statistic: 55.57299647096482
#   JB P-Value: 8.560066625192022e-13
# P-Value Test for BallControl:
#   P-Value Test Statistic: 51.17300840940605
#   P-Value: 7.725425569934107e-12
# T-Test for BallControl:
#   T-Test Statistic: 771.4237696931071
#   T-Test P-Value: 0.0
# Standard Error for BallControl: 0.09051083054333177
# Durbin-Watson Test for BallControl:
#   Durbin-Watson Statistic: 0.007462327750104293
# Jarque-Bera Test for SprintSpeed:
#   JB Test Statistic: 447.7159390483902
#   JB P-Value: 6.021699865951999e-98
# P-Value Test for SprintSpeed:
#   P-Value Test Statistic: 352.7174516405464
#   P-Value: 2.560816979683413e-77
# T-Test for SprintSpeed:
#   T-Test Statistic: 446.82054442407406
#   T-Test P-Value: 0.0
# Standard Error for SprintSpeed: 0.1566730040834719
# Durbin-Watson Test for SprintSpeed:
#   Durbin-Watson Statistic: 0.05127930687420073
# Jarque-Bera Test for LongShots:
#   JB Test Statistic: 95.58465113390808
#   JB P-Value: 1.7541096143419753e-21
# P-Value Test for LongShots:
#   P-Value Test Statistic: 92.26588493243506
#   P-Value: 9.219718324902631e-21
# T-Test for LongShots:
#   T-Test Statistic: 433.40922280555037
#   T-Test P-Value: 0.0
# Standard Error for LongShots: 0.14197399180215436
# Durbin-Watson Test for LongShots:
#   Durbin-Watson Statistic: 0.02680566964807946
# Jarque-Bera Test for Aggression:
#   JB Test Statistic: 143.58244502939235
#   JB P-Value: 6.629308241440613e-32
# P-Value Test for Aggression:
#   P-Value Test Statistic: 270.72424844952394
#   P-Value: 1.6329631728333641e-59
# T-Test for Aggression:
#   T-Test Statistic: 307.0132056691095
#   T-Test P-Value: 0.0
# Standard Error for Aggression: 0.19221787260054984
# Durbin-Watson Test for Aggression:
#   Durbin-Watson Statistic: 0.07131936684628754
# Jarque-Bera Test for Vision:
#   JB Test Statistic: 0.1719852152892584
#   JB P-Value: 0.9176010144278662
# P-Value Test for Vision:
#   P-Value Test Statistic: 0.1703992601275464
#   P-Value: 0.9183289400366783
# T-Test for Vision:
#   T-Test Statistic: 605.8745349403168
#   T-Test P-Value: 0.0
# Standard Error for Vision: 0.10886786735735215
# Durbin-Watson Test for Vision:
#   Durbin-Watson Statistic: 0.011613669105268912
# Jarque-Bera Test for BMI:
#   JB Test Statistic: 71.97830311187751
#   JB P-Value: 2.344823029686888e-16
# P-Value Test for BMI:
#   P-Value Test Statistic: 51.760402771732764
#   P-Value: 5.759321830767337e-12
# T-Test for BMI:
#   T-Test Statistic: 1248.6720094830193
#   T-Test P-Value: 0.0
# Standard Error for BMI: 0.018189871951776966
# Durbin-Watson Test for BMI:
#   Durbin-Watson Statistic: 0.0067755107201076204
# Jarque-Bera Test for Work Rate_NUM:
#   JB Test Statistic: 701.1283971476925
#   JB P-Value: 5.648108183120875e-153
# P-Value Test for Work Rate_NUM:
#   P-Value Test Statistic: 28153.39193254023
#   P-Value: 0.0
# T-Test for Work Rate_NUM:
#   T-Test Statistic: 120.11748979582705
#   T-Test P-Value: 0.0
# Standard Error for Work Rate_NUM: 0.04161835963056817
# Durbin-Watson Test for Work Rate_NUM:
#   Durbin-Watson Statistic: 0.5279016625955402

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Load your dataset (replace 'your_dataset.csv' with the actual file path)
data = pd.read_csv('final-mf.csv')

# Extract the predictor variables (independent variables) for which you want to check multicollinearity
# Replace 'X1', 'X2', 'X3', etc. with the actual column names of your predictor variables
X = data[['Age', 'Potential', 'Value', 'Crossing', 'ShortPassing', 'Dribbling',
       'LongPassing', 'BallControl', 'SprintSpeed', 'LongShots', 'Aggression',
       'Vision', 'BMI', 'Work Rate_NUM']]

# Add a constant (intercept) term to the predictor variables
X['intercept'] = 1

# Calculate VIF values
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display the VIF values
print(vif)
# Out:
#          Variable         VIF
# 0             Age    3.191567
# 1       Potential    4.124465
# 2           Value    1.786369
# 3        Crossing    2.435176
# 4    ShortPassing    8.461844
# 5       Dribbling    5.965182
# 6     LongPassing    5.419795
# 7     BallControl    8.917348
# 8     SprintSpeed    1.875234
# 9       LongShots    2.396707
# 10     Aggression    1.602598
# 11         Vision    4.311338
# 12            BMI    1.086614
# 13  Work Rate_NUM    1.140431
# 14      intercept  838.326875
